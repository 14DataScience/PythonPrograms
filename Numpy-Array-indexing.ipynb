# %%
#Numpy Array Indexing- Geeks for Geeks

# %% [markdown]
# 1. Accessing Elements in 1D Arrays

# %%
a = np.array([2,3,4,5,6,7])

# %%
import numpy as np

# %%
a = np.array([2,3,4,5,6,7,8])

# %%
a

# %%
a[0,3]

# %%
a[5]

# %%
matrix = np.array([[2,3,4],[5,6,7],[7,6,5]])

# %%
print(matrix[1,2])

# %%
print(matrix[2,2])

# %% [markdown]
# # matrix[depth, row, column].

# %%
cube = np.array([[[1,2,3],[4,5,6]],[[5,6,7],[8,9,10]],[[11,12,13],[34,67,89]]])

# %%
cube[1,1,2]

# %%
cube[2,1,2]

# %% [markdown]
# #3. Slicing Arrays

# %%
arr = np.array([3,4,5,6,7,8,9])

# %%
arr

# %%
arr[2:5]

# %%
matrix= np.array([[[23,45,67],[54,34,67]],[[11,22,33],[45,65,21]],[[22,33,44],[56,43,32]],[[37,91,92],[25,78,98]]])

# %% [markdown]
# # Slicing

# %%
matrix[1:,0:,1:]

# %%
matrix[:2,1:2,0:1]

# %%
matrix[::-1,:2,0:2]

# %%
matrix[::-2,0:1,0:2]

# %%
# 4. Boolean Indexing

# %% [markdown]
# # 4. Boolean Indexing

# %%
g = np.array([2,3,4,5,678,54,67,90,23,34,56])

# %%
g

# %%
print(g[g>23])

# %%
print(g[(g>20) & (g <200)])

# %%
arr = np.array([10, 20, 30, 40, 50])

# %%
indexes = [0,2,4]
arr[indexes]

# %%
print(arr[[0,2,4]])

# %%
# Modifying Array Elements

# %% [markdown]
# # Modifying Array Elements

# %%
arr = np.array([2,3,4,5,6,7])

# %%
arr[1:3] = 56
arr
