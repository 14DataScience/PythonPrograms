# %% [markdown]
# # Variables in Python

# %%
nit = 1030

# %%
1030= nit

# %%
Init = 10
Init

# %%
nit1 =20
nit1

# %%
nit = 20
NIT

# %%
nit

# %%
A = 5
a

# %%
A

# %%
nit@ = 5

# %%
nit_ = 5

# %%
nit_

# %%
nit$ = 6

# %%
_nit =5

# %%
_nit

# %%
import keyword
keyword.kwlist

# %%
len(keyword.kwlist)

# %%
for = 45
for

# %%
if = 67

# %%
else = 7
